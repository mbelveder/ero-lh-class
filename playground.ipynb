# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_BASE_PATH = '/Users/mike/Repos/classification_LH/data'
NNMAG_CAT_FILENAME = 'ERO_lhpv_03_23_sd01_a15_g14_desi_nway_match_21_10_22.gz_pkl'
DESI_MATCH_PATH = f'{DATA_BASE_PATH}/SB/{NNMAG_CAT_FILENAME}'
nn_df = pd.read_pickle(DESI_MATCH_PATH, compression='gzip')

nn_df
# Out:
#                 srcname_fin      RA_fin    DEC_fin        GLON       GLAT  \
# 0     SRGe J101903.3+563020  154.763934  56.505585  154.966043  50.066118
# 1     SRGe J101903.4+563325  154.764302  56.556994  154.897407  50.039645
# 2     SRGe J101911.0+562639  154.795822  56.444182  155.033709  50.112976
# 3     SRGe J101919.2+562429  154.830036  56.408006  155.066720  50.147889
# 4     SRGe J101922.0+560903  154.841764  56.150772  155.405891  50.286129
# ...                     ...         ...        ...         ...        ...
# 6880  SRGe J110729.8+585554  166.874345  58.931727  145.250371  53.458943
# 6881  SRGe J110736.7+585607  166.902963  58.935301  145.227690  53.465908
# 6882  SRGe J110749.6+583509  166.956762  58.585899  145.578454  53.747952
# 6883  SRGe J110815.1+583836  167.062714  58.643462  145.444178  53.740719
# 6884  SRGe J110820.3+584414  167.084550  58.737305  145.325970  53.677158
#
#         pos_r98  DET_LIKE_0     ML_FLUX_0  ML_FLUX_ERR_0   ML_CTS_0  ...  \
# 0      9.267930   15.858959  2.171120e-14   5.650445e-15  28.800014  ...
# 1     12.232697   16.660557  2.758328e-14   6.850312e-15  34.209091  ...
# 2      7.855049   18.953989  1.654359e-14   3.709296e-15  40.391277  ...
# 3      4.879086   85.512062  3.591936e-14   4.602094e-15  95.826859  ...
# 4     11.880253   22.144621  2.186130e-14   4.563695e-15  48.452347  ...
# ...         ...         ...           ...            ...        ...  ...
# 6880  11.156574   16.566111  2.304341e-14   6.882798e-15  18.639772  ...
# 6881  10.089838   12.075073  2.024115e-14   6.595920e-15  16.373026  ...
# 6882  27.628298   10.642184  3.581123e-14   1.215960e-14  14.592738  ...
# 6883  14.433076   10.176067  4.053449e-14   1.432964e-14  12.914164  ...
# 6884   4.893389  146.370148  2.063387e-13   2.687357e-14  75.511696  ...
#
#       desi_rel_dered_lg(Fx/Fo_z)  desi_rel_dered_lg(Fx/Fo_z_corr)  \
# 0                     -14.568950                         0.210721
# 1                     -14.577820                         0.201851
# 2                     -13.547600                         1.232071
# 3                     -14.725513                         0.054159
# 4                     -13.970527                         0.809144
# ...                          ...                              ...
# 6880                  -14.902839                        -0.123167
# 6881                  -14.652714                         0.126957
# 6882                  -17.222106                        -2.442434
# 6883                  -14.532454                         0.247217
# 6884                  -14.207238                         0.572433
#
#       desi_rel_dered_lg(Fx/Fo_g)  desi_rel_dered_lg(Fx/Fo_g_corr)  \
# 0                     -14.342116                       -15.101109
# 1                     -14.324102                       -14.992699
# 2                     -13.355032                       -15.272633
# 3                     -14.386168                       -14.868724
# 4                     -13.334019                       -15.147009
# ...                          ...                              ...
# 6880                  -14.604737                       -15.060133
# 6881                  -14.577997                       -15.120850
# 6882                  -15.553358                       -14.803185
# 6883                  -14.436763                       -14.810714
# 6884                  -13.909276                       -14.094201
#
#       desi_rel_dered_lg(Fx/Fo_r)  desi_rel_dered_lg(Fx/Fo_r_corr)  \
# 0                     -14.467482                        -0.011061
# 1                     -14.526816                        -0.070395
# 2                     -13.370449                         1.085971
# 3                     -14.614206                        -0.157786
# 4                     -13.312544                         1.143876
# ...                          ...                              ...
# 6880                  -14.764507                        -0.308086
# 6881                  -14.556631                        -0.100210
# 6882                  -16.232868                        -1.776447
# 6883                  -14.537269                        -0.080848
# 6884                  -14.014935                         0.441485
#
#       nway_n_match_flag_0  nway_n_match_flag_2  nway_is_closest  \
# 0                      14                    0            False
# 1                       9                    0            False
# 2                       7                    0             True
# 3                      15                    0             True
# 4                      11                    0             True
# ...                   ...                  ...              ...
# 6880                   20                    0            False
# 6881                   13                    0             True
# 6882                    8                    0             True
# 6883                   13                    0            False
# 6884                   14                    0            False
#
#       nway_is_within_pos_r98
# 0                       True
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# ...                      ...
# 6880                    True
# 6881                    True
# 6882                    True
# 6883                    True
# 6884                   False
#
# [6885 rows x 208 columns]

# %%
SRGZ_PATH = '/Users/mike/Repos/XLF_LH/data/lhpv_03_23_sd01_a15_g14_srgz_CatA_XnX_model4_SQG_model5_v20221207'
full_srgz_df = pd.read_pickle(SRGZ_PATH, compression='gzip')
full_srgz_df.srcname_fin = full_srgz_df.srcname_fin.str.decode('utf-8')
# SRGz catalog (only best counterparts)
srgz_df = full_srgz_df.query('srg_match_flag==1').reset_index(drop=True)

srgz_df
# Out:
#                 srcname_fin      RA_fin    DEC_fin       ls_ra     ls_dec  \
# 0     SRGe J103744.3+571156  159.434594  57.198788  159.434616  57.198786
# 1     SRGe J110137.5+572926  165.406353  57.490464  165.406590  57.490908
# 2     SRGe J110537.6+585120  166.406669  58.855424  166.406781  58.855776
# 3     SRGe J102349.9+563347  155.958041  56.563186  155.957331  56.563114
# 4     SRGe J105057.2+593215  162.738144  59.537414  162.738727  59.537349
# ...                     ...         ...        ...         ...        ...
# 9220  SRGe J102315.1+561957  155.813071  56.332561  155.812616  56.332027
# 9221  SRGe J102332.5+562524  155.885436  56.423270  155.879914  56.422475
# 9222  SRGe J102235.0+561919  155.645874  56.321872  155.648139  56.320064
# 9223  SRGe J102223.5+562357  155.597875  56.399058  155.601032  56.399529
# 9224  SRGe J104406.3+545413  161.026353  54.903612  161.021590  54.911042
#
#       ls_gaia_star_sn5 ls_type          g         W2     W1-W2  ...  \
# 0                False  b'PSF'  16.071100  14.227472  0.232485  ...
# 1                 True  b'PSF'  11.904632  11.610381 -0.594908  ...
# 2                False  b'PSF'  16.937919  13.750024  0.514789  ...
# 3                False  b'SER'  17.861058  15.267308  0.345680  ...
# 4                False  b'SER'  16.314963  15.017790 -0.126033  ...
# ...                ...     ...        ...        ...       ...  ...
# 9220             False  b'REX'  23.426028  20.671173 -0.520157  ...
# 9221             False  b'REX'  23.626739  20.075799 -0.013245  ...
# 9222             False  b'EXP'  22.811548  19.815725 -0.327937  ...
# 9223             False  b'REX'  20.962829  19.551222 -0.426255  ...
# 9224             False  b'PSF'  22.975101  21.316435  0.639038  ...
#
#       srg_match_pqso  srg_match_pgal  srg_match_SQG  srgz_z_max  \
# 0           0.998431        0.000566            QSO    0.484100
# 1           0.000086        0.000014           STAR    3.451000
# 2           0.998536        0.000732            QSO    0.113899
# 3           0.990481        0.009517            QSO    0.218920
# 4           0.572569        0.426983            QSO    0.072828
# ...              ...             ...            ...         ...
# 9220        0.270387        0.698193         GALAXY    0.812094
# 9221        0.889209        0.109669            QSO    1.578971
# 9222        0.020910        0.954320         GALAXY    2.639066
# 9223        0.003038        0.971443         GALAXY    0.200525
# 9224        0.995716        0.002909            QSO    2.258693
#
#       srgz_z_maxConf  srgz_z_merr68  srgz_z_perr68  srgz_z_model  \
# 0           0.530473      -0.049300       0.240895      b'x1a20'
# 1           0.831718      -0.182488       0.059000      b'x1a20'
# 2           0.876352      -0.019364       0.053445      b'x1a35'
# 3           0.973567      -0.038154       0.013414      b'x1a35'
# 4           0.996527      -0.026058       0.017372      b'x1a35'
# ...              ...            ...            ...           ...
# 9220        0.374176      -0.141370       1.152712      b'x1a20'
# 9221        0.244552      -0.561389       0.860029      b'x1a21'
# 9222        0.275652      -1.571066       0.225784      b'x1a20'
# 9223        0.655152      -0.052178       0.082495      b'x1a35'
# 9224        0.225279      -1.411059       0.379091      b'x1a35'
#
#       srgz_z_warning                                         srgz_z_pdf
# 0                  0  [0.6527, 0.7190000000000001, 0.7396, 0.4827172...
# 1                  0  [3.466, 3.275, 3.455, 3.386, 3.456000000000000...
# 2                  0  [0.182, 0.0935, 0.1505, 0.1059, 0.1298706, 0.0...
# 3                  0  [0.1736, 0.2188, 0.17379999999999998, 0.1736, ...
# 4                  0  [0.071539, 0.08547868, 0.09432407, 0.085719896...
# ...              ...                                                ...
# 9220               0  [2.228, 3.0189999999999997, 1.29878245, 0.9547...
# 9221               0  [2.556, 1.440272, 1.747656, 1.527, 1.440272, 1...
# 9222               0  [2.781, 0.91060805, 2.7960000000000007, 2.682,...
# 9223               0  [0.194944, 0.2767024, 0.1916254, 0.18609389999...
# 9224               0  [0.2669747, 0.7458324000000001, 2.02857, 1.988...
#
# [9225 rows x 31 columns]

# %%
srgz_xray_df = pd.read_pickle(
    'data/output_data/srgz_xray.gz_pkl',
    compression='gzip'
    )

srgz_xray_df['nn_srgz_same'].sum()
# Out:
# 6075

# %%
SAVEPATH = 'data/output_data/srgz_xray.gz_pkl'
save_directory = os.path.dirname(SAVEPATH)

save_directory
# Out:
# 'data/output_data'

# %%
plt.hist(cmatch_df['nn_sep'], bins=100)

plt.yscale('log')

plt.show()

# %%
old_df = pd.read_pickle(
    'data/output_data/matched_and_classified_old.gz_pkl',
    compression='gzip'
    )

new_df = pd.read_pickle(
    'data/output_data/matched_and_classified.gz_pkl',
    compression='gzip'
    )

new_df.equals(old_df)
# Out:
# True

# %%
srgz_df = pd.read_pickle(
    'data/output_data/srgz_nnmag.gz_pkl',
    compression='gzip'
    )
